# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
fc=pd.read_csv('fashioncheck.csv')
fc
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 0               1   NaN    Male         Blouse     Clothing
# 1               2   NaN    Male        Sweater     Clothing
# 2               3   NaN    Male          Jeans     Clothing
# 3               4   NaN    Male        Sandals     Footwear
# 4               5   NaN    Male         Blouse     Clothing
# ...           ...   ...     ...            ...          ...
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
# 3899         3900  52.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                       NaN       Kentucky    L       Gray  Winter
# 1                       NaN          Maine    L     Maroon  Winter
# ...

# %%
fc.shape
# Out:
# (3900, 19)

# %%
fc.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3269.000000            3285.000000    3246.000000
# mean   1950.500000    43.973998              59.863014       3.744239
# std    1125.977353    15.216359              23.673623       0.719448
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.750000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
fc1=fc["Age"].value_counts()
fc1
# Out:
# Age
# 57.0    76
# 41.0    76
# 49.0    74
# 69.0    72
# 25.0    71
# 42.0    70
# 62.0    69
# 31.0    69
# 32.0    69
# 43.0    68
# 54.0    67
# 19.0    67
# 59.0    66
# 68.0    66
# 28.0    66
# 29.0    66
# 52.0    65
# 27.0    65
# 35.0    65
# 37.0    65
# 23.0    64
# 58.0    64
# 46.0    64
# 63.0    63
# 30.0    62
# 51.0    61
# 56.0    61
# 18.0    61
# 40.0    61
# 36.0    60
# 66.0    60
# 22.0    60
# 47.0    60
# 55.0    59
# 64.0    59
# 39.0    58
# 65.0    58
# 21.0    57
# 34.0    57
# 26.0    57
# 45.0    56
# 60.0    55
# 61.0    55
# 48.0    55
# 24.0    55
# 50.0    55
# 38.0    55
# 53.0    54
# 33.0    54
# 70.0    54
# 67.0    48
# 20.0    48
# 44.0    47
# Name: count, dtype: int64

# %%
fc2=fc["Gender"].value_counts()
fc2
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %%
fc3=list(fc['Gender'].value_counts().keys())
fc3
# Out:
# ['Male', 'Female']

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fc['Gender'].value_counts().keys()),list(fc['Gender'].value_counts()),color="g")
plt.grid(True)
plt.show()

plt.pie(fc2,labels=fc3,autopct="%0.1f%%")
plt.show()

# %%
fc4=fc["Item Purchased"].value_counts()
fc4
# Out:
# Item Purchased
# Blouse        171
# Jewelry       171
# Pants         171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Belt          161
# Sunglasses    161
# Coat          161
# Sandals       160
# Socks         159
# Skirt         158
# Shorts        157
# Scarf         157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,5))
plt.bar(list(fc['Item Purchased'].value_counts().keys()),list(fc['Item Purchased'].value_counts()),color="g")
plt.grid(True)
plt.show()

# %%
fc5=fc["Category"].value_counts()
fc5
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
fc6=list(fc['Category'].value_counts().keys())
fc6
# Out:
# ['Clothing', 'Accessories', 'Footwear', 'Outerwear']

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fc['Category'].value_counts().keys()),list(fc['Category'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.pie(fc5,labels=fc6,autopct="%0.1f%%")
plt.show()

# %%
fc7=fc["Purchase Amount (USD)"].value_counts()
fc7
# Out:
# Purchase Amount (USD)
# 51.0     54
# 25.0     54
# 36.0     53
# 90.0     51
# 32.0     51
#          ..
# 100.0    31
# 86.0     30
# 54.0     29
# 61.0     27
# 69.0     26
# Name: count, Length: 81, dtype: int64

# %%
fc8=fc["Location"].value_counts()
fc8
# Out:
# Location
# Montana           96
# California        95
# Idaho             93
# Illinois          92
# Alabama           89
# Minnesota         88
# Nebraska          87
# New York          87
# Nevada            87
# Maryland          86
# Delaware          86
# Vermont           85
# Louisiana         84
# North Dakota      83
# Missouri          81
# West Virginia     81
# New Mexico        81
# Mississippi       80
# Indiana           79
# Georgia           79
# Kentucky          79
# Arkansas          79
# North Carolina    78
# Connecticut       78
# Virginia          77
# Ohio              77
# Tennessee         77
# Texas             77
# Maine             77
# South Carolina    76
# Colorado          75
# Oklahoma          75
# Wisconsin         75
# Oregon            74
# Pennsylvania      74
# Washington        73
# Michigan          73
# Alaska            72
# Massachusetts     72
# Wyoming           71
# Utah              71
# New Hampshire     71
# South Dakota      70
# ...

# %%
plt.figure(figsize=(100,40))
plt.bar(list(fc['Location'].value_counts().keys()),list(fc['Location'].value_counts()),color="g")
plt.grid(True)
plt.show()

# %%
fc9=fc["Size"].value_counts()
fc9
# Out:
# Size
# M     1755
# L     1053
# S      663
# XL     429
# Name: count, dtype: int64

# %%
fc10=list(fc['Size'].value_counts().keys())
fc10
# Out:
# ['M', 'L', 'S', 'XL']

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fc['Size'].value_counts().keys()),list(fc['Size'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.pie(fc9,labels=fc10,autopct="%0.1f%%")
plt.show()

# %%
fc11=fc["Color"].value_counts()
fc11
# Out:
# Color
# Olive        177
# Yellow       174
# Silver       173
# Teal         172
# Green        169
# Black        167
# Cyan         166
# Violet       166
# Gray         159
# Maroon       158
# Orange       154
# Charcoal     153
# Pink         153
# Magenta      152
# Blue         152
# Purple       151
# Peach        149
# Red          148
# Beige        147
# Indigo       147
# Lavender     147
# Turquoise    145
# White        142
# Brown        141
# Gold         138
# Name: count, dtype: int64

# %%
fc12=list(fc['Color'].value_counts().keys())
fc12
# Out:
# ['Olive',
#  'Yellow',
#  'Silver',
#  'Teal',
#  'Green',
#  'Black',
#  'Cyan',
#  'Violet',
#  'Gray',
#  'Maroon',
#  'Orange',
#  'Charcoal',
#  'Pink',
#  'Magenta',
#  'Blue',
#  'Purple',
#  'Peach',
#  'Red',
#  'Beige',
#  'Indigo',
#  'Lavender',
#  'Turquoise',
#  'White',
#  'Brown',
#  'Gold']

# %%
plt.figure(figsize=(20,5))
plt.bar(list(fc['Color'].value_counts().keys()),list(fc['Color'].value_counts()),color="g")
plt.grid(True)
plt.show()

# %%
fc13=fc["Season"].value_counts()
fc13
# Out:
# Season
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: count, dtype: int64

# %%
fc14=list(fc['Season'].value_counts().keys())
fc14
# Out:
# ['Spring', 'Fall', 'Winter', 'Summer']

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fc['Season'].value_counts().keys()),list(fc['Season'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.pie(fc13,labels=fc14,autopct="%0.1f%%")
plt.show()

# %%
Review_Rating=fc.iloc[0:,10]
Review_Rating
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 3895    4.2
# 3896    4.5
# 3897    2.9
# 3898    3.8
# 3899    3.1
# Name: Review Rating, Length: 3900, dtype: float64

# %%
Review_Rating.min()
# Out:
# 2.5

# %%
Review_Rating.mean()
# Out:
# 3.744239063462723

# %%
Review_Rating.max()
# Out:
# 5.0

# %%
Subscription_Status=fc.iloc[0:,11]
Subscription_Status
# Out:
# 0        yep
# 1        Yes
# 2        Yes
# 3        Yes
# 4         Yo
#         ...
# 3895      No
# 3896    ille
# 3897      No
# 3898       N
# 3899      No
# Name: Subscription Status, Length: 3900, dtype: object

# %%
fc15=fc["Subscription Status"].value_counts()
fc15
# Out:
# Subscription Status
# No           1698
# Yes           628
# n             151
# FALSE         150
# Naaji         150
# Nakko         150
# ille          141
# N             138
# Nope          136
# Nah           133
# Indeed         58
# TRUE           51
# y              49
# yep            47
# Haan           46
# Of course      46
# Yo             44
# Haanji         43
# Y              41
# Name: count, dtype: int64

# %%
Subscription_Status.min()
# Out:
# 'FALSE'

# %%
Subscription_Status.max()
# Out:
# 'yep'

# %%
Payment_Method=fc.iloc[0:,12]
Payment_Method
# Out:
# 0         Credit Card
# 1       Bank Transfer
# 2                Cash
# 3              PayPal
# 4                Cash
#             ...
# 3895             Cash
# 3896           PayPal
# 3897      Credit Card
# 3898           PayPal
# 3899    Bank Transfer
# Name: Payment Method, Length: 3900, dtype: object

# %%
fc16=fc["Payment Method"].value_counts()
fc16
# Out:
# Payment Method
# Credit Card      696
# Venmo            653
# Cash             648
# PayPal           638
# Debit Card       633
# Bank Transfer    632
# Name: count, dtype: int64

# %%
Payment_Method.min()
# Out:
# 'Bank Transfer'

# %%
Payment_Method.max()
# Out:
# 'Venmo'

# %%
fc17=list(fc['Payment Method'].value_counts().keys())
fc17
# Out:
# ['Credit Card', 'Venmo', 'Cash', 'PayPal', 'Debit Card', 'Bank Transfer']

# %%
plt.figure(figsize=(8,6))
plt.bar(list(fc['Payment Method'].value_counts().keys()),list(fc['Payment Method'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.pie(fc16,labels=fc17,autopct="%0.1f%%")
plt.show()

# %%
fc18=fc["Shipping Type"].value_counts()
fc18
# Out:
# Shipping Type
# Free Shipping     675
# Standard          654
# Store Pickup      650
# Next Day Air      648
# Express           646
# 2-Day Shipping    627
# Name: count, dtype: int64

# %%
fc19=list(fc['Shipping Type'].value_counts().keys())
fc19
# Out:
# ['Free Shipping',
#  'Standard',
#  'Store Pickup',
#  'Next Day Air',
#  'Express',
#  '2-Day Shipping']

# %%
plt.figure(figsize=(8,6))
plt.bar(list(fc['Shipping Type'].value_counts().keys()),list(fc['Shipping Type'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.pie(fc18,labels=fc19,autopct="%0.1f%%")
plt.show()

# %%
fc20=fc["Discount Applied"].value_counts()
fc20
# Out:
# Discount Applied
# No           1338
# Yes          1000
# Nah           124
# FALSE         123
# Nakko         111
# ille          109
# Nope          109
# N             108
# n             103
# Naaji          98
# Indeed         87
# Yo             85
# y              84
# Haan           79
# Y              74
# Of course      73
# TRUE           69
# yep            66
# Haanji         60
# Name: count, dtype: int64

# %%
fc21=list(fc['Discount Applied'].value_counts().keys())
fc21
# Out:
# ['No',
#  'Yes',
#  'Nah',
#  'FALSE',
#  'Nakko',
#  'ille',
#  'Nope',
#  'N',
#  'n',
#  'Naaji',
#  'Indeed',
#  'Yo',
#  'y',
#  'Haan',
#  'Y',
#  'Of course',
#  'TRUE',
#  'yep',
#  'Haanji']

# %%
fc22=fc["Frequency of Purchases"].value_counts()
fc22
# Out:
# Frequency of Purchases
# Every 3 Months    584
# Annually          572
# Quarterly         563
# Monthly           553
# Bi-Weekly         547
# Fortnightly       542
# Weekly            539
# Name: count, dtype: int64

# %%
fc23=list(fc['Frequency of Purchases'].value_counts().keys())
fc23
# Out:
# ['Every 3 Months',
#  'Annually',
#  'Quarterly',
#  'Monthly',
#  'Bi-Weekly',
#  'Fortnightly',
#  'Weekly']

# %%
plt.figure(figsize=(8,6))
plt.bar(list(fc['Frequency of Purchases'].value_counts().keys()),list(fc['Frequency of Purchases'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.pie(fc22,labels=fc23,autopct="%0.1f%%")
plt.show()
